# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
#enlevons les warnings
# %matplotlib inline

# %%
df = pd.read_csv('rest/rural-population-with-improved-water.csv')
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1991
# 1     Afghanistan  AFG  1992
# 2     Afghanistan  AFG  1993
# 3     Afghanistan  AFG  1994
# 4     Afghanistan  AFG  1995
# 5     Afghanistan  AFG  1996
# 6     Afghanistan  AFG  1997
# 7     Afghanistan  AFG  1998
# 8     Afghanistan  AFG  1999
# 9     Afghanistan  AFG  2000
# 10    Afghanistan  AFG  2001
# 11    Afghanistan  AFG  2002
# 12    Afghanistan  AFG  2003
# 13    Afghanistan  AFG  2004
# 14    Afghanistan  AFG  2005
# 15    Afghanistan  AFG  2006
# 16    Afghanistan  AFG  2007
# 17    Afghanistan  AFG  2008
# 18    Afghanistan  AFG  2009
# 19    Afghanistan  AFG  2010
# 20    Afghanistan  AFG  2011
# 21    Afghanistan  AFG  2012
# 22    Afghanistan  AFG  2013
# 23    Afghanistan  AFG  2014
# 24    Afghanistan  AFG  2015
# 25        Albania  ALB  1994
# 26        Albania  ALB  1995
# 27        Albania  ALB  1996
# 28        Albania  ALB  1997
# 29        Albania  ALB  1998
# ...           ...  ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6153 entries, 0 to 6152
# Data columns (total 4 columns):
# Entity                                                                                                  6153 non-null object
# Code                                                                                                    4983 non-null object
# Year                                                                                                    6153 non-null int64
# Improved water source, rural (% of rural population with access) (% of rural population with access)    6153 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 192.4+ KB

# %%
df.isna().sum()
df.fillna('Other')
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1991
# 1     Afghanistan  AFG  1992
# 2     Afghanistan  AFG  1993
# 3     Afghanistan  AFG  1994
# 4     Afghanistan  AFG  1995
# 5     Afghanistan  AFG  1996
# 6     Afghanistan  AFG  1997
# 7     Afghanistan  AFG  1998
# 8     Afghanistan  AFG  1999
# 9     Afghanistan  AFG  2000
# 10    Afghanistan  AFG  2001
# 11    Afghanistan  AFG  2002
# 12    Afghanistan  AFG  2003
# 13    Afghanistan  AFG  2004
# 14    Afghanistan  AFG  2005
# 15    Afghanistan  AFG  2006
# 16    Afghanistan  AFG  2007
# 17    Afghanistan  AFG  2008
# 18    Afghanistan  AFG  2009
# 19    Afghanistan  AFG  2010
# 20    Afghanistan  AFG  2011
# 21    Afghanistan  AFG  2012
# 22    Afghanistan  AFG  2013
# 23    Afghanistan  AFG  2014
# 24    Afghanistan  AFG  2015
# 25        Albania  ALB  1994
# 26        Albania  ALB  1995
# 27        Albania  ALB  1996
# 28        Albania  ALB  1997
# 29        Albania  ALB  1998
# ...           ...  ...   ...
# ...

# %%
df.boxplot()

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x='Year', y='Improved water source, rural (% of rural population with access) (% of rural population with access)', data=df[df['Entity']=='United States'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x='Year', y='Improved water source, rural (% of rural population with access) (% of rural population with access)', data=df[df['Entity']=='India'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x='Year', y='Improved water source, rural (% of rural population with access) (% of rural population with access)', data=df[df['Entity']=='Mali'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x='Year', y='Improved water source, rural (% of rural population with access) (% of rural population with access)', data=df[df['Entity']=='Palestine'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x='Year', y='Improved water source, rural (% of rural population with access) (% of rural population with access)', data=df[df['Entity']=='Somalia'])

# %%
plt.subplots(figsize=(25,7))
sns.lineplot(x='Year', y='Improved water source, rural (% of rural population with access) (% of rural population with access)', hue="Entity", data=df.nsmallest(200, 'Improved water source, rural (% of rural population with access) (% of rural population with access)'))

# %% [raw]
# Les progressions sont plus nuancés sur les régions rural. Surtout dans les pays du continent Africain. Les pourcentages sont aussi très faible jusqu'a 12%. Il y a clairement une favorisation des endroits urbanisés.

# %%
df = pd.read_csv('rest/urban-population-with-improved-water.csv')
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1991
# 1     Afghanistan  AFG  1992
# 2     Afghanistan  AFG  1993
# 3     Afghanistan  AFG  1994
# 4     Afghanistan  AFG  1995
# 5     Afghanistan  AFG  1996
# 6     Afghanistan  AFG  1997
# 7     Afghanistan  AFG  1998
# 8     Afghanistan  AFG  1999
# 9     Afghanistan  AFG  2000
# 10    Afghanistan  AFG  2001
# 11    Afghanistan  AFG  2002
# 12    Afghanistan  AFG  2003
# 13    Afghanistan  AFG  2004
# 14    Afghanistan  AFG  2005
# 15    Afghanistan  AFG  2006
# 16    Afghanistan  AFG  2007
# 17    Afghanistan  AFG  2008
# 18    Afghanistan  AFG  2009
# 19    Afghanistan  AFG  2010
# 20    Afghanistan  AFG  2011
# 21    Afghanistan  AFG  2012
# 22    Afghanistan  AFG  2013
# 23    Afghanistan  AFG  2014
# 24    Afghanistan  AFG  2015
# 25        Albania  ALB  1990
# 26        Albania  ALB  1991
# 27        Albania  ALB  1992
# 28        Albania  ALB  1993
# 29        Albania  ALB  1994
# ...           ...  ...   ...
# ...

# %%
df.boxplot()

# %%
df = pd.read_csv('data/urban-population-with-improved-water.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6308 entries, 0 to 6307
# Data columns (total 4 columns):
# Entity                                                                                                  6308 non-null object
# Code                                                                                                    5138 non-null object
# Year                                                                                                    6308 non-null int64
# Improved water source, urban (% of urban population with access) (% of urban population with access)    6308 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 197.2+ KB

# %%
sns.barplot(x = 'Improved water source, urban (% of urban population with access) (% of urban population with access)',y ='Entity' ,data=df.nsmallest(100, 'Improved water source, urban (% of urban population with access) (% of urban population with access)'))

# %%
sns.barplot(x = 'Improved water source, urban (% of urban population with access) (% of urban population with access)',y ='Entity' ,data=df.nlargest(150, 'Improved water source, urban (% of urban population with access) (% of urban population with access)'))

# %%
plt.subplots(figsize=(25,7))
sns.lineplot(x='Year', y='Improved water source, urban (% of urban population with access) (% of urban population with access)', hue="Entity", data=df.nsmallest(200, 'Improved water source, urban (% of urban population with access) (% of urban population with access)'))

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='United States'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='Mali'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='India'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='Nigeria'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='China'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='Palestine'])

# %%
plt.subplots(figsize=(18,7))
sns.lineplot(x="Year", y='Improved water source, urban (% of urban population with access) (% of urban population with access)', data=df[df['Entity']=='South Sudan'])

# %% [raw]
# Les etats Unis montrent une légère baisse au court. La tendance général va vers une progression pour chaque Pays. Palestine est le seul pays ayant une forte diminution entre 95-2000. Une tendance encourageante mais encore faible pour certains pays. (50à60%) et ceux dans les lieux urbains.
#
# Mali : 90%
