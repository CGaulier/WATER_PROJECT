# %%
#agricultural-water-withdrawals.csv
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
#enlevons les warnings
# %matplotlib inline

# %%
df = pd.read_csv('data/plastic-top-20-rivers.csv')
df
# Out:
#                                                Entity      Code  Year  \
# 0                                              Africa       NaN  2015
# 1            Amazon (Brazil, Peru, Colombia, Ecuador)       NaN  2015
# 2                                                Asia       NaN  2015
# 3                                   Australia-Pacific       NaN  2015
# 4                                 Brantas (Indonesia)       NaN  2015
# 5                             Central & North America       NaN  2015
# 6                           Cross (Nigeria, Cameroon)       NaN  2015
# 7                                        Dong (China)       NaN  2015
# 8                                              Europe       NaN  2015
# 9                          Ganges (India, Bangladesh)       NaN  2015
# 10                                   Hanjiang (China)       NaN  2015
# 11                                    Huangpu (China)       NaN  2015
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
# Entity                                     27 non-null object
# Code                                       1 non-null object
# Year                                       27 non-null int64
# Plastic mass input from rivers (tonnes)    27 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 944.0+ bytes

# %%
plt.subplots(figsize=(25,18))
sns.barplot(x='Plastic mass input from rivers (tonnes)',y='Entity',data=df.nlargest(10, 'Plastic mass input from rivers (tonnes)'))

# %%
df['Plastic mass input from rivers (tonnes)'].value_counts()
# Out:
# 38900      2
# 16700      1
# 333000     1
# 3900       1
# 13600      1
# 40300      1
# 67400      1
# 17100      1
# 1210000    1
# 12900      1
# 13400      1
# 21500      1
# 19100      1
# 40800      1
# 73900      1
# 109200     1
# 35300      1
# 1404200    1
# 11900      1
# 300        1
# 22800      1
# 32500      1
# 38800      1
# 115000     1
# 14700      1
# 12800      1
# Name: Plastic mass input from rivers (tonnes), dtype: int64

# %%
df1 = pd.read_csv('data/surface-plastic-mass-by-ocean.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
# Entity                             7 non-null object
# Code                               0 non-null float64
# Year                               7 non-null int64
# All sizes (total mass) (tonnes)    7 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 304.0+ bytes

# %%
plt.subplots(figsize=(25,18))
sns.barplot(x='Entity',y='All sizes (total mass) (tonnes)',data=df1)
df1.Entity.value_counts()
# Out:
# South Atlantic          1
# South Pacific           1
# Indian Ocean            1
# North Atlantic          1
# North Pacific           1
# Mediterranean Sea       1
# Global ocean (total)    1
# Name: Entity, dtype: int64

# %%
df2 = pd.read_csv('data/plasticmovment.csv')
df2
# Out:
#        year  month  lat  lng  probability
# 0         0      0   23   62      1.00000
# 1         0      2   20   61      0.00313
# 2         0      2   20   62      0.01929
# 3         0      2   21   60      0.00730
# 4         0      2   21   61      0.08916
# 5         0      2   21   62      0.01460
# 6         0      2   22   60      0.00209
# 7         0      2   22   61      0.07716
# 8         0      2   22   62      0.01981
# 9         0      2   22   63      0.00782
# 10        0      2   22   64      0.03858
# 11        0      2   22   65      0.01408
# 12        0      2   23   59      0.00730
# 13        0      2   23   60      0.03650
# 14        0      2   23   61      0.04745
# 15        0      2   23   62      0.04588
# 16        0      2   23   63      0.03337
# 17        0      2   23   64      0.00313
# 18        0      2   23   65      0.00104
# 19        0      2   24   57      0.00417
# 20        0      2   24   58      0.01043
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56174 entries, 0 to 56173
# Data columns (total 5 columns):
# year           56174 non-null int64
# month          56174 non-null int64
# lat            56174 non-null int64
# lng            56174 non-null int64
# probability    56174 non-null float64
# dtypes: float64(1), int64(4)
# memory usage: 2.1 MB

# %%
df2.lng.mean()
# Out:
# 72.79403282657456

# %%
#mouvement des plastic dans la mer
plt.subplots(figsize=(25,18))
ax = sns.lineplot(x='year', y="lng", data=df2)

# %%
d = {'land': [32180559], 'underwater': [83239], 'watercraft':[152429]}
df = pd.DataFrame(data=d)
df.plot.bar()

# %%
df3 = pd.read_csv('data/mdt_data.csv')
df3
# Out:
#        ListID             ListName  ItemID                   ItemName   LogID  \
# 0          22  Marine Debris Items     175       Aluminum or tin cans  228800
# 1          22  Marine Debris Items     179             Plastic Bottle  228801
# 2          22  Marine Debris Items     205           Plastic Utensils  228802
# 3          22  Marine Debris Items     175       Aluminum or tin cans  228803
# 4          22  Marine Debris Items     177               Plastic Bags  228804
# 5          22  Marine Debris Items     187                 Cigarettes  228805
# 6          22  Marine Debris Items     177               Plastic Bags  228806
# 7          22  Marine Debris Items     187                 Cigarettes  228807
# 8          22  Marine Debris Items     175       Aluminum or tin cans  228808
# 9          22  Marine Debris Items     175       Aluminum or tin cans  228809
# 10         22  Marine Debris Items     177               Plastic Bags  228810
# ...

# %%
de = df3['Material Description'].value_counts()

# %%
da = df3['Material Description'].str.contains('PLASTIC').value_counts()

# %%
plt.subplots(figsize=(25,18))
de.plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df3.Location.value_counts().nlargest(20).plot.bar()

# %%
df4 = pd.read_csv('data/marinepollutiondata2017to2018.csv')

df4
# Out:
#           Date      Region   Source     Ship Type            Area  \
# 0    5/07/2017  Townsville  Unknown       Unknown     Port Limits
# 1    7/07/2017    Brisbane     Ship  Recreational     Port Limits
# 2    3/09/2017    Brisbane     Ship       Defence     Port Limits
# 3    6/09/2017  Townsville     Land       Unknown     Port limits
# 4   14/09/2017   Gladstone     Ship       Unknown     Port Limits
# 5   24/09/2017   Gladstone     Land    Commercial     Port Limits
# 6    4/10/2017   Gladstone     Ship  Recreational     Port Limits
# 7   11/10/2017    Brisbane  Unknown       Unknown     Port Limits
# 8   11/10/2017    Brisbane     Ship       Unknown     Port Limits
# 9   15/10/2017   Gladstone     Ship       Unknown     Port Limits
# 10  20/10/2017    Brisbane     Ship  Recreational  Coastal Waters
# 11  21/10/2017      Cairns     Ship    Commercial     Port Limits
# 12  25/10/2017      Cairns     Ship    Commercial     Port Limits
# ...

# %%
plt.subplots(figsize=(25,18))
df4.Pollutant.value_counts().plot.bar()

# %%
df4 = df4.replace('Unknown',0)

plt.subplots(figsize=(25,18))
sns.barplot(x=df4['Estimated Litres'].astype(float),y='Pollutant',data=df4)

# %%
df4 = df4.to_json()
df5 = pd.read_json(df4)

# %%
df5 = pd.read_csv('data/Potential_Oil_Spill_Risk_Locations.csv')
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 29 columns):
# X              108 non-null float64
# Y              108 non-null float64
# OBJECTID       110 non-null int64
# NAME           108 non-null object
# ID             108 non-null object
# LONG_DD        109 non-null float64
# LAT_DD         109 non-null float64
# LONG_DMS       109 non-null object
# LAT_DMS        109 non-null object
# SECTOR         109 non-null object
# STATE          108 non-null object
# COUNTY         108 non-null object
# PHYS_ADD       108 non-null object
# CITY           107 non-null object
# ZIP_CODE       107 non-null object
# CONTACT        105 non-null object
# CONTACT2       79 non-null object
# SITE_DESC      106 non-null object
# SITE_DESC2     79 non-null object
# SITE_DESC3     79 non-null object
# FACIL_TYPE     79 non-null object
# OIL_TYPES      106 non-null object
# PROB_RISK      79 non-null object
# MAX_RISK       79 non-null object
# ...

# %%
df5.STATE.value_counts().plot.bar()

# %%
df6 = pd.read_csv('data/alguesvertes2.csv')
df6
# Out:
#     OTUNumber    Kingdom      Supergroup     Division                Class  \
# 0    Otu00022  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 1    Otu00225  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 2    Otu00558  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 3    Otu00715  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 4    Otu00937  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 5    Otu01052  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 6    Otu01098  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 7    Otu01162  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 8    Otu01820  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 9    Otu02735  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# 10   Otu02949  Eukaryota  Archaeplastida  Chlorophyta  Chlorodendrophyceae
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 17 columns):
# OTUNumber           768 non-null object
# Kingdom             768 non-null object
# Supergroup          768 non-null object
# Division            768 non-null object
# Class               768 non-null object
# Order               768 non-null object
# Family              768 non-null object
# Genus               768 non-null object
# Species             488 non-null object
# Size                768 non-null int64
# OSD1                768 non-null int64
# OSD10               768 non-null int64
# OSD100_1m_depth     768 non-null int64
# OSD100_20m_depth    768 non-null int64
# OSD101              768 non-null int64
# OSD50               768 non-null int64
# OSD99               768 non-null int64
# dtypes: int64(8), object(9)
# memory usage: 102.1+ KB

# %%
df6.Species.value_counts()
# Out:
# Dolichomastigaceae-B_sp.                   47
# Chlorophyta_XXXX_sp.                       31
# Bathycoccus_prasinos                       28
# Ostreococcus_cladeB                        21
# Dolichomastix_tenuilepis                   21
# Halosphaera_sp.                            18
# Prasino-Clade-9-B_X_sp.                    16
# Picochlorum_sp.                            11
# Micromonas_Clade-A.ABC.1-2_I               10
# Crustomastigaceae-AB_sp.                   10
# Phaeophila_dendroides                      10
# Ostreococcus_lucimarinus                   10
# Acrochaete_leptochaete                      9
# Micromonas_Clade-A.ABC.1-2_II               8
# Ostreococcus_mediterraneus                  8
# Chlamydomonas_raudensis                     7
# Micromonas_Clade-B_lagoon-and-innerseas     7
# Mantoniella_sp.                             7
# Mamiella_gilva                              7
# Micromonas_Clade-B.E.3                      7
# ...

# %%
df6[df6['Family']=='Ulvales-relatives_X']
# Out:
#     OTUNumber    Kingdom      Supergroup     Division        Class  \
# 673  Otu00141  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 675  Otu00301  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 677  Otu00631  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 678  Otu00720  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 679  Otu01267  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 680  Otu01579  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 681  Otu02176  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 682  Otu02988  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 683  Otu03007  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 685  Otu03337  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 686  Otu03392  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 693  Otu04857  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# 694  Otu04897  Eukaryota  Archaeplastida  Chlorophyta  Ulvophyceae
# ...

# %%
plt.subplots(figsize=(25,18))
sns.barplot(x='Division' ,y='OSD100_1m_depth',data=df6.nlargest(15, 'OSD100_1m_depth'))
